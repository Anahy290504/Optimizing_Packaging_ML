# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv('data_for_models.csv', index_col=0)
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#         order_code display_name  qty_items_sold_item_1 sap_main_size_item_1  \
# 0       2114228695         BS 2                      1                   XL
# 1       2114231111         BS 1                      1                    S
# 2       2114233362        Klein                      1                    S
# 3       2114237231         BS 2                      1                  152
# 4       2114246737         BS 1                      1                    M
# ...            ...          ...                    ...                  ...
# 153171  2123472413         BS 1                      1                   52
# 153172  2123474591         BS 4                      1                   40
# 153173  2123476093         BS 3                      1                   37
# 153174  2123476871         BS 2                      1                   40
# 153175  2123480553         BS 8                      1                   26
#
#        product_navision_detail_category_item_1  weight_item_1  volume_item_1  \
# 0                                fahrradtrikot         363.03    4412.500000
# 1                           trainingshose lang         543.41    1467.770317
# 2                                    badeanzug         396.39    1191.740467
# 3                                    badeshort         343.06    4412.500000
# 4                                    shirt 1/2         377.41    4412.500000
# ...                                        ...            ...            ...
# 153171                             strickjacke         560.86    1396.188341
# 153172                                   boots        1254.71    3268.665240
# 153173                   stiefel / stiefelette        1151.06    4924.756954
# 153174                         boots gefüttert        1224.04    3810.023754
# 153175                                     NaN            NaN            NaN
#
#         label_item_1  height_item_1  qty_items_sold_item_2  \
# 0               True          914.0                    1.0
# 1               True          914.0                    1.0
# 2               True          914.0                    1.0
# 3               True          914.0                    1.0
# 4               True          914.0                    1.0
# ...              ...            ...                    ...
# 153171          True          914.0                    1.0
# 153172          True          914.0                    NaN
# 153173          True          914.0                    NaN
# 153174          True          914.0                    NaN
# 153175         False            NaN                    1.0
#
#        sap_main_size_item_2 product_navision_detail_category_item_2  \
# 0                        42                   business hemd l.a uni
# 1                        38                                   kleid
# 2                         S                               badeanzug
# 3                       152                               badeshort
# 4                         M                               shirt 1/2
# ...                     ...                                     ...
# 153171                    L                             strickjacke
# 153172                  NaN                                     NaN
# 153173                  NaN                                     NaN
# 153174                  NaN                                     NaN
# 153175                   30                                     NaN
#
#         weight_item_2  volume_item_2 label_item_2  height_item_2  \
# 0              488.01    1410.240894         True          914.0
# 1              516.74    1026.861070         True          914.0
# 2              396.39    1191.740467         True          914.0
# 3              343.06    4412.500000         True          914.0
# 4              377.41    4412.500000         True          914.0
# ...               ...            ...          ...            ...
# 153171         560.86    1396.188341         True          914.0
# 153172            NaN            NaN          NaN            NaN
# 153173            NaN            NaN          NaN            NaN
# 153174            NaN            NaN          NaN            NaN
# 153175            NaN            NaN        False            NaN
#
#         qty_items_sold_item_3 sap_main_size_item_3  \
# 0                         1.0                   42
# 1                         1.0                    M
# 2                         NaN                  NaN
# 3                         1.0                  W29
# 4                         1.0                   40
# ...                       ...                  ...
# 153171                    NaN                  NaN
# 153172                    NaN                  NaN
# 153173                    NaN                  NaN
# 153174                    NaN                  NaN
# 153175                    1.0                   30
#
#        product_navision_detail_category_item_3  weight_item_3  volume_item_3  \
# 0                        business hemd l.a uni         488.01    1410.240894
# 1                                          top         401.20     776.287085
# 2                                          NaN            NaN            NaN
# 3                                        jeans         649.92    1004.282603
# 4                                        jeans         649.92    1004.282603
# ...                                        ...            ...            ...
# 153171                                     NaN            NaN            NaN
# 153172                                     NaN            NaN            NaN
# 153173                                     NaN            NaN            NaN
# 153174                                     NaN            NaN            NaN
# 153175                                     NaN            NaN            NaN
#
#        label_item_3  height_item_3  qty_items_sold_item_4  \
# 0              True          914.0                    1.0
# 1              True          914.0                    1.0
# 2               NaN            NaN                    NaN
# 3              True          914.0                    1.0
# 4              True          914.0                    1.0
# ...             ...            ...                    ...
# 153171          NaN            NaN                    NaN
# 153172          NaN            NaN                    NaN
# 153173          NaN            NaN                    NaN
# 153174          NaN            NaN                    NaN
# 153175        False            NaN                    1.0
#
#        sap_main_size_item_4 product_navision_detail_category_item_4  \
# 0                       XXL                      t-shirt multipack
# 1                         M                           poloshirt 1/2
# 2                       NaN                                     NaN
# 3                         S                               pullunder
# 4                         M                               shirt 1/2
# ...                     ...                                     ...
# 153171                  NaN                                     NaN
# 153172                  NaN                                     NaN
# 153173                  NaN                                     NaN
# 153174                  NaN                                     NaN
# 153175                   30                                     NaN
#
#         weight_item_4  volume_item_4 label_item_4  height_item_4  \
# 0              552.28    1665.455381         True          914.0
# 1              433.69    4412.500000         True          914.0
# 2                 NaN            NaN          NaN            NaN
# 3              492.31    3279.107143         True          914.0
# 4              377.41    4412.500000         True          914.0
# ...               ...            ...          ...            ...
# 153171            NaN            NaN          NaN            NaN
# 153172            NaN            NaN          NaN            NaN
# 153173            NaN            NaN          NaN            NaN
# 153174            NaN            NaN          NaN            NaN
# 153175            NaN            NaN        False            NaN
#
#         qty_items_sold_item_5 sap_main_size_item_5  \
# 0                         1.0                  XXL
# 1                         1.0                    M
# 2                         NaN                  NaN
# 3                         1.0              140/146
# 4                         1.0                    M
# ...                       ...                  ...
# 153171                    NaN                  NaN
# 153172                    NaN                  NaN
# 153173                    NaN                  NaN
# 153174                    NaN                  NaN
# 153175                    1.0                   26
#
#        product_navision_detail_category_item_5  weight_item_5  volume_item_5  \
# 0                           t-shirt multipack          552.28    1665.455381
# 1                                          top         401.20     776.287085
# 2                                          NaN            NaN            NaN
# 3                                    badeshort         343.06    4412.500000
# 4                                    shirt 1/2         377.41    4412.500000
# ...                                        ...            ...            ...
# 153171                                     NaN            NaN            NaN
# 153172                                     NaN            NaN            NaN
# 153173                                     NaN            NaN            NaN
# 153174                                     NaN            NaN            NaN
# 153175                                     NaN            NaN            NaN
#
#        label_item_5  height_item_5  qty_items_sold_item_6  \
# 0              True          914.0                    1.0
# 1              True          914.0                    NaN
# 2               NaN            NaN                    NaN
# 3              True          556.0                    1.0
# 4              True          914.0                    1.0
# ...             ...            ...                    ...
# 153171          NaN            NaN                    NaN
# 153172          NaN            NaN                    NaN
# 153173          NaN            NaN                    NaN
# 153174          NaN            NaN                    NaN
# 153175        False            NaN                    1.0
#
#        sap_main_size_item_6 product_navision_detail_category_item_6  \
# 0                        43               business hemd l.a gemust.
# 1                       NaN                                     NaN
# 2                       NaN                                     NaN
# 3                         S                                     top
# 4                         M                             sweat hoody
# ...                     ...                                     ...
# 153171                  NaN                                     NaN
# 153172                  NaN                                     NaN
# 153173                  NaN                                     NaN
# 153174                  NaN                                     NaN
# 153175                   26                                     NaN
#
#         weight_item_6  volume_item_6 label_item_6  height_item_6  \
# 0              476.44    1962.252333         True          914.0
# 1                 NaN            NaN          NaN            NaN
# 2                 NaN            NaN          NaN            NaN
# 3              401.20     776.287085         True          914.0
# 4              612.78    2349.427953         True          914.0
# ...               ...            ...          ...            ...
# 153171            NaN            NaN          NaN            NaN
# 153172            NaN            NaN          NaN            NaN
# 153173            NaN            NaN          NaN            NaN
# 153174            NaN            NaN          NaN            NaN
# 153175            NaN            NaN        False            NaN
#
#         qty_items_sold_item_7 sap_main_size_item_7  \
# 0                         1.0                   43
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         1.0                    S
# 4                         1.0                    M
# ...                       ...                  ...
# 153171                    NaN                  NaN
# 153172                    NaN                  NaN
# 153173                    NaN                  NaN
# 153174                    NaN                  NaN
# 153175                    NaN                  NaN
#
#        product_navision_detail_category_item_7  weight_item_7  volume_item_7  \
# 0                        business hemd l.a uni         488.01    1410.240894
# 1                                          NaN            NaN            NaN
# 2                                          NaN            NaN            NaN
# 3                                          top         401.20     776.287085
# 4                                 pullover 1/2         491.15    2910.312500
# ...                                        ...            ...            ...
# 153171                                     NaN            NaN            NaN
# 153172                                     NaN            NaN            NaN
# 153173                                     NaN            NaN            NaN
# 153174                                     NaN            NaN            NaN
# 153175                                     NaN            NaN            NaN
#
#        label_item_7  height_item_7  qty_items_sold_item_8  \
# 0              True          914.0                    NaN
# 1               NaN            NaN                    NaN
# 2               NaN            NaN                    NaN
# 3              True          914.0                    1.0
# 4              True          914.0                    NaN
# ...             ...            ...                    ...
# 153171          NaN            NaN                    NaN
# 153172          NaN            NaN                    NaN
# 153173          NaN            NaN                    NaN
# 153174          NaN            NaN                    NaN
# 153175          NaN            NaN                    NaN
#
#        sap_main_size_item_8 product_navision_detail_category_item_8  \
# 0                       NaN                                     NaN
# 1                       NaN                                     NaN
# 2                       NaN                                     NaN
# 3                        XS                                     top
# 4                       NaN                                     NaN
# ...                     ...                                     ...
# 153171                  NaN                                     NaN
# 153172                  NaN                                     NaN
# 153173                  NaN                                     NaN
# 153174                  NaN                                     NaN
# 153175                  NaN                                     NaN
#
#         weight_item_8  volume_item_8 label_item_8  height_item_8  \
# 0                 NaN            NaN          NaN            NaN
# 1                 NaN            NaN          NaN            NaN
# 2                 NaN            NaN          NaN            NaN
# 3               401.2     776.287085         True          914.0
# 4                 NaN            NaN          NaN            NaN
# ...               ...            ...          ...            ...
# 153171            NaN            NaN          NaN            NaN
# 153172            NaN            NaN          NaN            NaN
# 153173            NaN            NaN          NaN            NaN
# 153174            NaN            NaN          NaN            NaN
# 153175            NaN            NaN          NaN            NaN
#
#         qty_items_sold_item_9 sap_main_size_item_9  \
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         1.0                    S
# 4                         NaN                  NaN
# ...                       ...                  ...
# 153171                    NaN                  NaN
# 153172                    NaN                  NaN
# 153173                    NaN                  NaN
# 153174                    NaN                  NaN
# 153175                    NaN                  NaN
#
#        product_navision_detail_category_item_9  weight_item_9  volume_item_9  \
# 0                                          NaN            NaN            NaN
# 1                                          NaN            NaN            NaN
# 2                                          NaN            NaN            NaN
# 3                                          top          401.2     776.287085
# 4                                          NaN            NaN            NaN
# ...                                        ...            ...            ...
# 153171                                     NaN            NaN            NaN
# 153172                                     NaN            NaN            NaN
# 153173                                     NaN            NaN            NaN
# 153174                                     NaN            NaN            NaN
# 153175                                     NaN            NaN            NaN
#
#        label_item_9  height_item_9  qty_items_sold_item_10  \
# 0               NaN            NaN                     NaN
# 1               NaN            NaN                     NaN
# 2               NaN            NaN                     NaN
# 3              True          914.0                     1.0
# 4               NaN            NaN                     NaN
# ...             ...            ...                     ...
# 153171          NaN            NaN                     NaN
# 153172          NaN            NaN                     NaN
# 153173          NaN            NaN                     NaN
# 153174          NaN            NaN                     NaN
# 153175          NaN            NaN                     NaN
#
#        sap_main_size_item_10 product_navision_detail_category_item_10  \
# 0                        NaN                                      NaN
# 1                        NaN                                      NaN
# 2                        NaN                                      NaN
# 3                          S                                shirt 1/2
# 4                        NaN                                      NaN
# ...                      ...                                      ...
# 153171                   NaN                                      NaN
# 153172                   NaN                                      NaN
# 153173                   NaN                                      NaN
# 153174                   NaN                                      NaN
# 153175                   NaN                                      NaN
#
#         weight_item_10  volume_item_10 label_item_10  height_item_10  \
# 0                  NaN             NaN           NaN             NaN
# 1                  NaN             NaN           NaN             NaN
# 2                  NaN             NaN           NaN             NaN
# 3               377.41          4412.5          True           914.0
# 4                  NaN             NaN           NaN             NaN
# ...                ...             ...           ...             ...
# 153171             NaN             NaN           NaN             NaN
# 153172             NaN             NaN           NaN             NaN
# 153173             NaN             NaN           NaN             NaN
# 153174             NaN             NaN           NaN             NaN
# 153175             NaN             NaN           NaN             NaN
#
#         qty_items_sold_item_11 sap_main_size_item_11  \
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# 2                          NaN                   NaN
# 3                          1.0                   W28
# 4                          NaN                   NaN
# ...                        ...                   ...
# 153171                     NaN                   NaN
# 153172                     NaN                   NaN
# 153173                     NaN                   NaN
# 153174                     NaN                   NaN
# 153175                     NaN                   NaN
#
#        product_navision_detail_category_item_11  weight_item_11  \
# 0                                           NaN             NaN
# 1                                           NaN             NaN
# 2                                           NaN             NaN
# 3                                         jeans          649.92
# 4                                           NaN             NaN
# ...                                         ...             ...
# 153171                                      NaN             NaN
# 153172                                      NaN             NaN
# 153173                                      NaN             NaN
# 153174                                      NaN             NaN
# 153175                                      NaN             NaN
#
#         volume_item_11 label_item_11  height_item_11  qty_items_sold_item_12  \
# 0                  NaN           NaN             NaN                     NaN
# 1                  NaN           NaN             NaN                     NaN
# 2                  NaN           NaN             NaN                     NaN
# 3          1004.282603          True           914.0                     NaN
# 4                  NaN           NaN             NaN                     NaN
# ...                ...           ...             ...                     ...
# 153171             NaN           NaN             NaN                     NaN
# 153172             NaN           NaN             NaN                     NaN
# 153173             NaN           NaN             NaN                     NaN
# 153174             NaN           NaN             NaN                     NaN
# 153175             NaN           NaN             NaN                     NaN
#
#        sap_main_size_item_12 product_navision_detail_category_item_12  \
# 0                        NaN                                      NaN
# 1                        NaN                                      NaN
# 2                        NaN                                      NaN
# 3                        NaN                                      NaN
# 4                        NaN                                      NaN
# ...                      ...                                      ...
# 153171                   NaN                                      NaN
# 153172                   NaN                                      NaN
# 153173                   NaN                                      NaN
# 153174                   NaN                                      NaN
# 153175                   NaN                                      NaN
#
#         weight_item_12  volume_item_12 label_item_12  height_item_12  \
# 0                  NaN             NaN           NaN             NaN
# 1                  NaN             NaN           NaN             NaN
# 2                  NaN             NaN           NaN             NaN
# 3                  NaN             NaN           NaN             NaN
# 4                  NaN             NaN           NaN             NaN
# ...                ...             ...           ...             ...
# 153171             NaN             NaN           NaN             NaN
# 153172             NaN             NaN           NaN             NaN
# 153173             NaN             NaN           NaN             NaN
# 153174             NaN             NaN           NaN             NaN
# 153175             NaN             NaN           NaN             NaN
#
#         qty_items_sold_item_13 sap_main_size_item_13  \
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# 2                          NaN                   NaN
# 3                          NaN                   NaN
# 4                          NaN                   NaN
# ...                        ...                   ...
# 153171                     NaN                   NaN
# 153172                     NaN                   NaN
# 153173                     NaN                   NaN
# 153174                     NaN                   NaN
# 153175                     NaN                   NaN
#
#        product_navision_detail_category_item_13  weight_item_13  \
# 0                                           NaN             NaN
# 1                                           NaN             NaN
# 2                                           NaN             NaN
# 3                                           NaN             NaN
# 4                                           NaN             NaN
# ...                                         ...             ...
# 153171                                      NaN             NaN
# 153172                                      NaN             NaN
# 153173                                      NaN             NaN
# 153174                                      NaN             NaN
# 153175                                      NaN             NaN
#
#         volume_item_13 label_item_13  height_item_13  qty_items_sold_item_14  \
# 0                  NaN           NaN             NaN                     NaN
# 1                  NaN           NaN             NaN                     NaN
# 2                  NaN           NaN             NaN                     NaN
# 3                  NaN           NaN             NaN                     NaN
# 4                  NaN           NaN             NaN                     NaN
# ...                ...           ...             ...                     ...
# 153171             NaN           NaN             NaN                     NaN
# 153172             NaN           NaN             NaN                     NaN
# 153173             NaN           NaN             NaN                     NaN
# 153174             NaN           NaN             NaN                     NaN
# 153175             NaN           NaN             NaN                     NaN
#
#        sap_main_size_item_14 product_navision_detail_category_item_14  \
# 0                        NaN                                      NaN
# 1                        NaN                                      NaN
# 2                        NaN                                      NaN
# 3                        NaN                                      NaN
# 4                        NaN                                      NaN
# ...                      ...                                      ...
# 153171                   NaN                                      NaN
# 153172                   NaN                                      NaN
# 153173                   NaN                                      NaN
# 153174                   NaN                                      NaN
# 153175                   NaN                                      NaN
#
#         weight_item_14  volume_item_14 label_item_14  height_item_14  \
# 0                  NaN             NaN           NaN             NaN
# 1                  NaN             NaN           NaN             NaN
# 2                  NaN             NaN           NaN             NaN
# 3                  NaN             NaN           NaN             NaN
# 4                  NaN             NaN           NaN             NaN
# ...                ...             ...           ...             ...
# 153171             NaN             NaN           NaN             NaN
# 153172             NaN             NaN           NaN             NaN
# 153173             NaN             NaN           NaN             NaN
# 153174             NaN             NaN           NaN             NaN
# 153175             NaN             NaN           NaN             NaN
#
#         qty_items_sold_item_15 sap_main_size_item_15  \
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# 2                          NaN                   NaN
# 3                          NaN                   NaN
# 4                          NaN                   NaN
# ...                        ...                   ...
# 153171                     NaN                   NaN
# 153172                     NaN                   NaN
# 153173                     NaN                   NaN
# 153174                     NaN                   NaN
# 153175                     NaN                   NaN
#
#        product_navision_detail_category_item_15  weight_item_15  \
# 0                                           NaN             NaN
# 1                                           NaN             NaN
# 2                                           NaN             NaN
# 3                                           NaN             NaN
# 4                                           NaN             NaN
# ...                                         ...             ...
# 153171                                      NaN             NaN
# 153172                                      NaN             NaN
# 153173                                      NaN             NaN
# 153174                                      NaN             NaN
# 153175                                      NaN             NaN
#
#         volume_item_15 label_item_15  height_item_15
# 0                  NaN           NaN             NaN
# 1                  NaN           NaN             NaN
# 2                  NaN           NaN             NaN
# 3                  NaN           NaN             NaN
# 4                  NaN           NaN             NaN
# ...                ...           ...             ...
# 153171             NaN           NaN             NaN
# 153172             NaN           NaN             NaN
# 153173             NaN           NaN             NaN
# 153174             NaN           NaN             NaN
# 153175             NaN           NaN             NaN
#
# [153176 rows x 107 columns]

# %%
# Prepare features and target values, converting non-numeric data to numeric and filling missing values
X = df.drop(columns=['display_name']).apply(pd.to_numeric, errors='coerce').fillna(0).values
y = df['display_name'].values

# Encode target labels into integers
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Split data into training and testing sets with stratified sampling
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# %%
# Initialize the CatBoost classifier with hyperparameters and GPU support
model = CatBoostClassifier(
    iterations=1300,
    learning_rate=0.4,
    depth=4,
    l2_leaf_reg=2,
    loss_function='MultiClass',
    verbose=100,
    random_seed=42,
    task_type='GPU'
)

# Train the model and evaluate on the test set
model.fit(X_train, y_train, eval_set=(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Cell In[6], line 14
#       2 model = CatBoostClassifier(
#       3     iterations=1300,
#       4     learning_rate=0.4,
#    (...)
#      10     task_type='GPU'
#      11 )
#      13 # Train the model and evaluate on the test set
# ---> 14 model.fit(X_train, y_train, eval_set=(X_test, y_test))
#
# File ~\miniconda3\envs\CapstoneProject\Lib\site-packages\catboost\core.py:5201, in CatBoostClassifier.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5198 if 'loss_function' in params:
#    5199     CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
# -> 5201 self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    5202           eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    5203           silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5204 return self
#
# File ~\miniconda3\envs\CapstoneProject\Lib\site-packages\catboost\core.py:2396, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2393 allow_clear_pool = train_params["allow_clear_pool"]
#    2395 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2396     self._train(
#    2397         train_pool,
#    2398         train_params["eval_sets"],
#    2399         params,
#    2400         allow_clear_pool,
#    2401         train_params["init_model"]
#    2402     )
#    2404 # Have property feature_importance possibly set
#    2405 loss = self._object._get_loss_function_name()
#
# File ~\miniconda3\envs\CapstoneProject\Lib\site-packages\catboost\core.py:1776, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1775 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1776     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1777     self._set_trained_model_attributes()
#
# File _catboost.pyx:4833, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4882, in _catboost._CatBoost._train()
#
# CatBoostError: C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/cuda/cuda_lib/cuda_base.h:281: CUDA error 35: CUDA driver version is insufficient for CUDA runtime version

# %%
# Predict class labels on the test set
y_pred = model.predict(X_test)
y_pred_classes = y_pred.flatten() if len(y_pred.shape) > 1 else y_pred

# %%
# Generate and print the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

# Generate and print the classification report
report = classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_)
print("Classification Report:")
print(report)
# Out:
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Cell In[6], line 27
#      14 X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)
#      16 model = CatBoostClassifier(
#      17     iterations=1300,
#      18     learning_rate=0.4,
#    (...)
#      24     task_type='GPU'
#      25 )
# ---> 27 model.fit(X_train, y_train, eval_set=(X_test, y_test))
#      29 y_pred = model.predict(X_test)
#      30 y_pred_classes = y_pred.flatten() if len(y_pred.shape) > 1 else y_pred
#
# File ~\miniconda3\envs\CapstoneProject\Lib\site-packages\catboost\core.py:5201, in CatBoostClassifier.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5198 if 'loss_function' in params:
#    5199     CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
# -> 5201 self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    5202           eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    5203           silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5204 return self
#
# File ~\miniconda3\envs\CapstoneProject\Lib\site-packages\catboost\core.py:2396, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2393 allow_clear_pool = train_params["allow_clear_pool"]
#    2395 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2396     self._train(
#    2397         train_pool,
#    2398         train_params["eval_sets"],
#    2399         params,
#    2400         allow_clear_pool,
#    2401         train_params["init_model"]
#    2402     )
#    2404 # Have property feature_importance possibly set
#    2405 loss = self._object._get_loss_function_name()
#
# File ~\miniconda3\envs\CapstoneProject\Lib\site-packages\catboost\core.py:1776, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1775 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1776     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1777     self._set_trained_model_attributes()
#
# File _catboost.pyx:4833, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4882, in _catboost._CatBoost._train()
#
# CatBoostError: C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/cuda/cuda_lib/cuda_base.h:281: CUDA error 35: CUDA driver version is insufficient for CUDA runtime version

# %%
# Get feature importances from the trained model using the training data
feature_importances = model.get_feature_importance(data=Pool(X_train, y_train))

# Extract feature names from the DataFrame, excluding the target column
feature_names = df.drop(columns=['display_name']).columns

# Create a DataFrame to pair feature names with their corresponding importances
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# %%
importance_df.head(20)
# Out:
#                    Feature  Importance
# 4            weight_item_1   19.866878
# 5            volume_item_1   12.611933
# 11           weight_item_2   11.196718
# 0               order_code   10.233425
# 18           weight_item_3    6.134248
# 12           volume_item_2    5.449689
# 2     sap_main_size_item_1    5.177102
# 25           weight_item_4    3.459410
# 15   qty_items_sold_item_3    3.245132
# 19           volume_item_3    3.098471
# 9     sap_main_size_item_2    2.401697
# 32           weight_item_5    2.038350
# 8    qty_items_sold_item_2    1.899182
# 7            height_item_1    1.585138
# 26           volume_item_4    1.470646
# 16    sap_main_size_item_3    1.151631
# 39           weight_item_6    0.973701
# 21           height_item_3    0.727169
# 33           volume_item_5    0.647196
# 14           height_item_2    0.612484
# 23    sap_main_size_item_4    0.608523
# 46           weight_item_7    0.591168
# 53           weight_item_8    0.450727
# 43   qty_items_sold_item_7    0.369278
# 30    sap_main_size_item_5    0.349426
# 28           height_item_4    0.321266
# 60           weight_item_9    0.319648
# 35           height_item_5    0.284615
# 40           volume_item_6    0.277252
# 47           volume_item_7    0.250743
# 74          weight_item_11    0.244927
# 67          weight_item_10    0.225836
# 36   qty_items_sold_item_6    0.214903
# 22   qty_items_sold_item_4    0.181163
# 37    sap_main_size_item_6    0.178912
# 61           volume_item_9    0.128066
# 49           height_item_7    0.115784
# 54           volume_item_8    0.109483
# 44    sap_main_size_item_7    0.108850
# 64  qty_items_sold_item_10    0.103285
# 56           height_item_8    0.078399
# 68          volume_item_10    0.065074
# 89          volume_item_13    0.051152
# 81          weight_item_12    0.043079
# 75          volume_item_11    0.042165
# 1    qty_items_sold_item_1    0.041320
# 51    sap_main_size_item_8    0.036352
# 42           height_item_6    0.035676
# 58    sap_main_size_item_9    0.029395
# 65   sap_main_size_item_10    0.028254

# %%
# Extract the category part of each feature name and add it as a new column
importance_df['Category'] = importance_df['Feature'].str.extract(r'([a-zA-Z_]+)')

# Calculate the cumulative importance for each feature category
category_importances = importance_df.groupby('Category')['Importance'].sum().sort_values(ascending=False)

# Plot the cumulative feature importances by category as a horizontal bar chart
plt.figure(figsize=(10, 6))
category_importances.plot(kind='barh')
plt.xlabel('Cumulative Importance')
plt.ylabel('Feature Category')
plt.title('Cumulative Feature Importances by Category')
plt.gca().invert_yaxis()  # Reverse the order for better visualization
plt.show()
